# %%
from scipy import linalg
import numpy as np

test = int(input("enter no. of tests: "))

for i in range(test):
  x = int(input())
  ans = np.matrix(x)
  binput = input().split(" ")
  l1 = [float(binput[0]),float(binput[1])]
  l2 = [float(binput[2]),float(binput[3])]
  b = np.array([l1, l2])
  cinput = input().split(" ")
  l3 = [[float(cinput[0])],[float(cinput[1])]]
  c = np.array(l3)
  bc = np.dot(b,c)
  p = bc[0,0]
  q = bc[1,0]
  
  total = (x-q)/(p-q)
  print (total, 1-total)
