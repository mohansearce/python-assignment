# %%
#define the multiply function
def multiply(no_1, no_2, boundary):
  if no_1*no_2 > boundary:
    print("multiplication of ", no_1, " and ", no_2, " with bound ", boundary, " is not possible")
    return
  else:
    product = no_1*no_2
    print (product)
    return

#take users input
q = int(input("Enter the no. of queries: "))
print("No. of queries q=", q )

if q >= 1 and q <= 1000:
  #take values of a,b and bound
  s=[]
  for i in range(q):
    s.append(input("enter the query "))
    ss = s[i].split()

    if len(ss) == 3:
      a = int(ss[0])
      b = int(ss[1])
      bound = int(ss[2])
      if a >= 1 and b >= 1 and bound >= a and bound >= b and bound <= 100000:
        multiply(a,b,bound)
# Out:
# Enter the no. of queries: 1000000
# No. of queries q= 1000000

# %%
_
